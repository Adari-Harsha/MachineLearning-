# %% [markdown]
# ## From the given Dataset. Print the processed dataset after implementation.
#
# ### Write the following functions.
#
# - A function to delete duplicate values
# - Function to fill the missing values(i.e values having 0 ) with the mean of coressponding class of the attribute
# - Function to transform the nominal attributes into numerical values,by removing the colour attribute and transforming the three new colours (Green, yellow and Red) into numerical values.
# - Function to normalise the values using min-max method.

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\sande\OneDrive\Desktop\MMSO\Machine Learning\ML_assignment02_dataset_2022.csv")
df.head()
# Out:
#   Colour  Radius (cm)  Weight (grams) Fruit (class)
# 0  Green          4.3             122          Pear
# 1  Green          4.6             152          Pear
# 2  Green          3.1              85         Apple
# 3  Green          3.6             173          Pear
# 4  Green          2.5              65         Lemon

# %%
df.shape
# Out:
# (35, 4)

# %%
df.describe()
# Out:
#        Radius (cm)  Weight (grams)
# count    35.000000       35.000000
# mean      3.097143       86.485714
# std       1.180101       40.437585
# min       0.000000        0.000000
# 25%       2.450000       62.000000
# 50%       3.100000       80.000000
# 75%       4.100000      116.000000
# max       5.200000      173.000000

# %%
df
# Out:
#     Colour  Radius (cm)  Weight (grams) Fruit (class)
# 0    Green          4.3             122          Pear
# 1    Green          4.6             152          Pear
# 2    Green          3.1              85         Apple
# 3    Green          3.6             173          Pear
# 4    Green          2.5              65         Lemon
# 5    Green          2.5              70         Apple
# 6    Green          2.7              73         Apple
# 7    Green          4.5             110          Pear
# 8    Green          2.5              86         Apple
# 9    Green          2.4              68         Lemon
# 10   Green          4.2             126          Pear
# 11     Red          3.7             101         Apple
# 12     Red          3.7             100         Apple
# 13     Red          3.4              80         Apple
# 14  Yellow          3.2              79         Apple
# 15  Yellow          3.1              69         Lemon
# ...

# %%
def normalise_minmax(x):
    c = (x - x.min())/(x.max()-x.min())
    return c

# %%
df
# Out:
#     Colour  Radius (cm)  Weight (grams) Fruit (class)
# 0    Green          4.3             122          Pear
# 1    Green          4.6             152          Pear
# 2    Green          3.1              85         Apple
# 3    Green          3.6             173          Pear
# 4    Green          2.5              65         Lemon
# 5    Green          2.5              70         Apple
# 6    Green          2.7              73         Apple
# 7    Green          4.5             110          Pear
# 8    Green          2.5              86         Apple
# 9    Green          2.4              68         Lemon
# 10   Green          4.2             126          Pear
# 11     Red          3.7             101         Apple
# 12     Red          3.7             100         Apple
# 13     Red          3.4              80         Apple
# 14  Yellow          3.2              79         Apple
# 15  Yellow          3.1              69         Lemon
# ...

# %%
df.head()
# Out:
#   Colour  Radius (cm)  Weight (grams) Fruit (class)
# 0  Green          4.3             122          Pear
# 1  Green          4.6             152          Pear
# 2  Green          3.1              85         Apple
# 3  Green          3.6             173          Pear
# 4  Green          2.5              65         Lemon

# %%
print(df.columns.tolist())
# Out:
# ['Colour', 'Radius (cm)', 'Weight (grams)', 'Fruit (class)']

# %%
dummies = pd.get_dummies(df.Colour)

# %%
new_data = pd.concat([df,dummies],axis = 'columns')
new_df = new_data.drop(['Colour'],axis ='columns')
print(new_df)
# Out:
#     Radius (cm)  Weight (grams) Fruit (class)  Green  Red  Yellow
# 0           4.3             122          Pear      1    0       0
# 1           4.6             152          Pear      1    0       0
# 2           3.1              85         Apple      1    0       0
# 3           3.6             173          Pear      1    0       0
# 4           2.5              65         Lemon      1    0       0
# 5           2.5              70         Apple      1    0       0
# 6           2.7              73         Apple      1    0       0
# 7           4.5             110          Pear      1    0       0
# 8           2.5              86         Apple      1    0       0
# 9           2.4              68         Lemon      1    0       0
# 10          4.2             126          Pear      1    0       0
# 11          3.7             101         Apple      0    1       0
# 12          3.7             100         Apple      0    1       0
# ...

# %%
def transfor_nominal(x):
    dummies = pd.get_dummies(x.Colour);
    new_data = pd.concat([x,dummies],axis = 'columns')
    new_df = new_data.drop(['Colour'],axis ='columns')
    return new_df

# %%
transfor_nominal(df)
# Out:
#     Radius (cm)  Weight (grams) Fruit (class)  Green  Red  Yellow
# 0           4.3             122          Pear      1    0       0
# 1           4.6             152          Pear      1    0       0
# 2           3.1              85         Apple      1    0       0
# 3           3.6             173          Pear      1    0       0
# 4           2.5              65         Lemon      1    0       0
# 5           2.5              70         Apple      1    0       0
# 6           2.7              73         Apple      1    0       0
# 7           4.5             110          Pear      1    0       0
# 8           2.5              86         Apple      1    0       0
# 9           2.4              68         Lemon      1    0       0
# 10          4.2             126          Pear      1    0       0
# 11          3.7             101         Apple      0    1       0
# 12          3.7             100         Apple      0    1       0
# ...

# %%
df.fillna(2)
# Out:
#     Colour  Radius (cm)  Weight (grams) Fruit (class)
# 0    Green          4.3             122          Pear
# 1    Green          4.6             152          Pear
# 2    Green          3.1              85         Apple
# 3    Green          3.6             173          Pear
# 4    Green          2.5              65         Lemon
# 5    Green          2.5              70         Apple
# 6    Green          2.7              73         Apple
# 7    Green          4.5             110          Pear
# 8    Green          2.5              86         Apple
# 9    Green          2.4              68         Lemon
# 10   Green          4.2             126          Pear
# 11     Red          3.7             101         Apple
# 12     Red          3.7             100         Apple
# 13     Red          3.4              80         Apple
# 14  Yellow          3.2              79         Apple
# 15  Yellow          3.1              69         Lemon
# ...

# %%
ds= pd.read_csv(r"C:\Users\sande\OneDrive\Desktop\MMSO\Machine Learning\ML_assignment02_dataset_2022.csv")

# %%
df.loc[(df['Weight (grams)'] == 0), 'Weight (grams)'] = df['Weight (grams)'].mean()
df
# Out:
#     Colour  Radius (cm)  Weight (grams) Fruit (class)
# 0    Green          4.3      122.000000          Pear
# 1    Green          4.6      152.000000          Pear
# 2    Green          3.1       85.000000         Apple
# 3    Green          3.6      173.000000          Pear
# 4    Green          2.5       65.000000         Lemon
# 5    Green          2.5       70.000000         Apple
# 6    Green          2.7       73.000000         Apple
# 7    Green          4.5      110.000000          Pear
# 8    Green          2.5       86.000000         Apple
# 9    Green          2.4       68.000000         Lemon
# 10   Green          4.2      126.000000          Pear
# 11     Red          3.7      101.000000         Apple
# 12     Red          3.7      100.000000         Apple
# 13     Red          3.4       80.000000         Apple
# 14  Yellow          3.2       79.000000         Apple
# 15  Yellow          3.1       69.000000         Lemon
# ...

# %%
def fill_values(x):
    df.loc[(x==0), x] = x.mean()
    return df

# %%
def del_duplicate(x):
    x = x.drop_duplicates()
    return x

# %%
df.shape
# Out:
# (35, 4)

# %%
(df.drop_duplicates()).shape
# Out:
# (33, 4)

# %%
df.shape
# Out:
# (35, 4)

# %%
del_duplicate(df)
# Out:
#     Colour  Radius (cm)  Weight (grams) Fruit (class)
# 0    Green          4.3      122.000000          Pear
# 1    Green          4.6      152.000000          Pear
# 2    Green          3.1       85.000000         Apple
# 3    Green          3.6      173.000000          Pear
# 4    Green          2.5       65.000000         Lemon
# 5    Green          2.5       70.000000         Apple
# 6    Green          2.7       73.000000         Apple
# 7    Green          4.5      110.000000          Pear
# 8    Green          2.5       86.000000         Apple
# 9    Green          2.4       68.000000         Lemon
# 10   Green          4.2      126.000000          Pear
# 11     Red          3.7      101.000000         Apple
# 12     Red          3.7      100.000000         Apple
# 13     Red          3.4       80.000000         Apple
# 14  Yellow          3.2       79.000000         Apple
# 15  Yellow          3.1       69.000000         Lemon
# ...

# %%
print("min :",df['Radius (cm)'].min())
print("max :",df['Radius (cm)'].max())
print(4.3-2.1/5.2-2.1)
# Out:
# min : 0.0
# max : 5.2
# 1.796153846153846
